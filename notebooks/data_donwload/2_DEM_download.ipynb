# %% [markdown]
# # Digital Elevation Model Download
#
# This notebook downloads the Digital Elevation Model - DEM, from The National Map using the TNM Rest API. API documentation is [available here](https://tnmaccess.nationalmap.gov/api/v1/docs).

# %%
# Import modules
import requests
from pathlib import Path
import json
import sys
import os
import warnings
import re
from datetime import datetime
from IPython.display import display, Markdown
import json
from dotenv import load_dotenv

# %%
# Root path
project_root_path = Path.cwd().parent.parent

# Supress warnings
warnings.filterwarnings("ignore")

# %%
# Add 'src' to system path
sys.path.append(str(project_root_path / 'src'))

# Import modules
from data_download.download import download_GeoTIFF

# %%
# Load tokens
load_dotenv(project_root_path / '.env')

NOAA_API_TOKEN = os.getenv('NOAA_API_TOKEN')

# %% [markdown]
# ## Screening and Availability Assessment of 1/3 Arc-Second Resolution DEM
#
# This section focuses on accessing and evaluating the availability of high-resolution (1/3 arc-second, approximately 10-meter resolution) Digital Elevation Model (DEM) data for the defined study area using the U.S. Geological Survey (USGS) National Map (TNM) API.
#
# The accompanying code queries the TNM API to retrieve metadata for all 1/3 arc-second DEM tiles that intersect the spatial extent of the study region. This metadata includes essential information for each available tile, such as unique identifiers, spatial extent, and direct download links.
#
# Following the retrieval of the list of available high-resolution DEM tiles within the study area, the total cumulative file size required to download all these tiles is calculated. This calculation is performed to assess the overall data volume and evaluate the computational resources (storage, memory, processing time) needed to effectively work with the 1/3 arc-second resolution data. Based on this total size assessment, a determination will be made regarding the feasibility of utilizing the high-resolution DEMs or if transitioning to a coarser resolution dataset is necessary to ensure efficient processing throughout the project.

# %%
# Load the study area bounding box
study_area_bbox_path = project_root_path / 'data' / 'silver'/ 'geo' /'json' / 'study_area_bbox.json'
with open(study_area_bbox_path, 'r') as f:
    study_area_bbox_dic = json.load(f)

# Build the box as a string for feeding the request in the parameters
corners = ['bottom_left', 'bottom_right', 'top_right', 'top_left']
pairs = [f"{study_area_bbox_dic[corner][0]} {study_area_bbox_dic[corner][1]}" for corner in corners]
bbox = ",".join(pairs)

# Define the base URL for the TNM API
base_url = "https://tnmaccess.nationalmap.gov/api/v1/"

product = "National Elevation Dataset (NED) 1/3 arc-second"

# Define parameters for the API request to query available datasets
params = {
    "polygon": bbox,  # Specify the area to search for
    "datasets": product,  
    "outputFormat": "JSON",
    "max": 1000
}

# Send a GET request to the API
response_dem_availabilty = requests.get(base_url + "products", params=params)

# Check if the request was successful
if response_dem_availabilty.status_code == 200:
    # Parse the JSON response
    response_dem_availabilty_json = response_dem_availabilty.json()
    
    # Display the dataset information
    display(Markdown(f'**{len(response_dem_availabilty_json.get("items",[]))} files were found. Displaying the first 5:**\n '))
    count =  0
    for dataset in response_dem_availabilty_json.get("items", []):
        count += 1
        if count > 5:
            break
        print(f"- Name: {dataset['title']}")
        print(f"  Publication Date: {dataset['publicationDate']}")
        print(f"  Description: {dataset['body']}")
        print(f"  Metadata URL: {dataset['metaUrl']}\n")
else:
    print(f"Failed to retrieve data. HTTP Status Code: {response_dem_availabilty.status_code}")
# Out:
# **379 files were found. Displaying the first 5:**
# - Name: USGS 1/3 Arc Second n36w078 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c7
#
# - Name: USGS 1/3 Arc Second n36w079 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c5
#
# - Name: USGS 1/3 Arc Second n36w080 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b89d34e9bcc607bd4c1
#
# - Name: USGS 1/3 Arc Second n36w081 20240510
#   Publication Date: 2024-05-10
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/6642f00cd34e1955f5a4202e
#
# - Name: USGS 1/3 Arc Second n36w081 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b88d34e9bcc607bd4bf

# %% [markdown]
# From the response returned, there area **379** GeoTiff file to download. However, there are multiple file for the same area, from different dates (for example, file name *USGS 1/3 Arc Second n36w081 20240510* and *USGS 1/3 Arc Second n36w081 20240611* are both for area n36w081, but for dates *2024-05-10* and *2024-06-11* respectvely). For this study it will always be used the latest file.
#
# The code below, filters the latest file for each region. Before, proceeding, however, the raw list of available files is saved in the bronze data folder. |

# %%
# Save raw list
available_dem_list_path = project_root_path / 'data/bronze/json_docs/available_10m_dem_list.json'
available_dem_list_path.parent.mkdir(parents=True, exist_ok=True)
with open(available_dem_list_path, 'w', encoding='utf-8') as f:
    json.dump(response_dem_availabilty_json, f, ensure_ascii=False, indent=4)

# %%
def filter_latest_geotiff(data):

    region_latest = {}
    
    for item in data:
        # Extract region from title using regex pattern (e.g., n41w074)
        match = re.search(r'n\d+w\d+', item['title'], re.IGNORECASE)
        if not match:
            continue
        region = match.group(0).lower()

        # Parse publication date
        pub_date = datetime.strptime(item['publicationDate'], '%Y-%m-%d')

        # If region is new or found a later publication date, update the entry
        if region not in region_latest or pub_date > datetime.strptime(region_latest[region]['publicationDate'], '%Y-%m-%d'):
            region_latest[region] = item

    # Return unique latest items for each region
    return list(region_latest.values())

dem_all_items = response_dem_availabilty_json.get("items",[])
dem_filtered_data = filter_latest_geotiff(data = dem_all_items)

# Display the dataset information
display(Markdown(f'**{len(dem_filtered_data)} unique files were found. Displaying the first 5:**\n '))
count =  0
for dataset in dem_filtered_data:
    count += 1
    if count > 5:
        break
    print(f"- Name: {dataset['title']}")
    print(f"  Publication Date: {dataset['publicationDate']}")
    print(f"  Description: {dataset['body']}")
    print(f"  Metadata URL: {dataset['metaUrl']}\n")
# Out:
# **104 unique files were found. Displaying the first 5:**
# - Name: USGS 1/3 Arc Second n36w078 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c7
#
# - Name: USGS 1/3 Arc Second n36w079 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c5
#
# - Name: USGS 1/3 Arc Second n36w080 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b89d34e9bcc607bd4c1
#
# - Name: USGS 1/3 Arc Second n36w081 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b88d34e9bcc607bd4bf
#
# - Name: USGS 1/3 Arc Second n36w082 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b86d34e9bcc607bd4bd

# %%
dem_filtered_data[0]
# Out:
# {'title': 'USGS 1/3 Arc Second n36w078 20250507',
#  'moreInfo': 'This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as [...]',
#  'sourceId': '681c128ed4be0260c2c465c7',
#  'sourceName': 'ScienceBase',
#  'sourceOriginId': None,
#  'sourceOriginName': 'gda',
#  'metaUrl': 'https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c7',
#  'vendorMetaUrl': 'https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/metadata/NC_HurricaneFlorence_2020_D20/NC_HurricaneFlorence_9_2020',
#  'publicationDate': '2025-05-07',
#  'lastUpdated': '2025-05-07T20:12:06.396-06:00',
#  'dateCreated': '2025-05-07T20:10:22.397-06:00',
#  'sizeInBytes': 517373038,
#  'extent': '1 x 1 degree',
#  'format': 'GeoTIFF',
#  'downloadURL': 'https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n36w078/USGS_13_n36w078_20250507.tif',
#  'downloadURLRaster': None,
#  'previewGraphicURL': 'https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n36w078/USGS_13_n36w078_20250507.jpg',
#  'downloadLazURL': None,
#  'urls': {'TIFF': 'https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n36w078/USGS_13_n36w078_20250507.tif'},
#  'datasets': [],
#  'boundingBox': {'minX': -78.0005555557936,
#   'maxX': -76.99944444360551,
#   'minY': 34.9994444441067,
#   'maxY': 36.000555556294785},
#  'bestFitIndex': 0.0,
#  'body': 'This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.',
#  'processingUrl': 'processingUrl',
#  'modificationInfo': '2025-05-07'}

# %% [markdown]
# **Get the total size**

# %%
try:
    # Use a HEAD request to get only the headers
    url = dem_filtered_data[0]['downloadURL']
    response = requests.head(url)

    # Check if the request was successful
    response.raise_for_status()

    # Get the Content-Length header, which is the file size in bytes
    content_length = response.headers.get('Content-Length')

    if content_length:
        file_size_bytes = int(content_length)
        print(f"File: {url}")
        print(f"  Size: {file_size_bytes/1e6} mega bytes")
        print("-" * 20)
    else:
        print(f"Could not get Content-Length for {url}")
        print("-" * 20)

except requests.exceptions.RequestException as e:
    print(f"Error fetching metadata for {url}: {e}")
    print("-" * 20)
# Out:
# File: https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n36w078/USGS_13_n36w078_20250507.tif
#   Size: 517.373038 mega bytes
# --------------------

# %%
def get_total_tiff_size(file_urls):
    total_size_bytes = 0
    processed_count = 0 # To keep track of successfully processed files

    # Iterate through the URLs and get file sizes
    for url in file_urls:
        try:
            # Use a HEAD request to get only the headers
            # Set a reasonable timeout to avoid hanging indefinitely
            response = requests.head(url, timeout=10)

            # Check if the request was successful (status code 2xx)
            response.raise_for_status()

            # Get the Content-Length header, which is the file size in bytes
            content_length = response.headers.get('Content-Length')

            if content_length:
                try:
                    file_size_bytes = int(content_length)
                    total_size_bytes += file_size_bytes
                    processed_count += 1
                    print(f"Successfully retrieved size for {url}: {file_size_bytes} bytes")
                except ValueError:
                    print(f"Warning: Could not convert Content-Length to integer for {url}")
            else:
                print(f"Warning: Could not get Content-Length for {url}")

        except requests.exceptions.Timeout:
            print(f"Error: Request timed out for {url}")
        except requests.exceptions.ConnectionError:
             print(f"Error: Failed to connect to {url}")
bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w089/USGS_13_n43w089_20241107.tif: 429632426 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w090/USGS_13_n43w090_20240625.tif: 450890153 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n40w084/USGS_13_n40w084_20200302.tif: 435241716 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w082/USGS_13_n43w082_20130911.tif: 119822317 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w083/USGS_13_n43w083_20190401.tif: 111003402 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w084/USGS_13_n43w084_20190412.tif: 422168827 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w086/USGS_13_n43w086_20191107.tif: 449417234 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/13/TIFF/historical/n43w087/USGS_13_n43w087_20190308.tif: 144532529 bytes
#
# --- Summary ---
# Attempted to process 104 URLs.
# Successfully processed 104 URLs.
# Total size of processed files: 45967.176899 Mega bytes
# ---------------

# %% [markdown]
# The total size of GeoTiff files is aproximately **46 Gb**. Which is beyond the scope of this study. Next, the total the 1 arc (30m) resolution is assessed.
#
# ## Screening and Availability Assessment of 1 Arc-Second Resolution DEM

# %%
product = "National Elevation Dataset (NED) 1 arc-second"

# Define parameters for the API request to query available datasets
params = {
    "polygon": bbox,  # Specify the area to search for
    "datasets": product,  
    "outputFormat": "JSON",
    "max": 1000
}

# Send a GET request to the API
response_dem_1arc_availabilty = requests.get(base_url + "products", params=params)

# Check if the request was successful
if response_dem_1arc_availabilty.status_code == 200:
    # Parse the JSON response
    response_dem_1arc_availabilty_json = response_dem_1arc_availabilty.json()
    
    # Display the dataset information
    display(Markdown(f'**{len(response_dem_1arc_availabilty_json.get("items",[]))} files were found. Displaying the first 5:**\n '))
    count =  0
    for dataset in response_dem_1arc_availabilty_json.get("items", []):
        count += 1
        if count > 5:
            break
        print(f"- Name: {dataset['title']}")
        print(f"  Publication Date: {dataset['publicationDate']}")
        print(f"  Description: {dataset['body']}")
        print(f"  Metadata URL: {dataset['metaUrl']}\n")
else:
    print(f"Failed to retrieve data. HTTP Status Code: {response_dem_1arc_availabilty.status_code}")
# Out:
# **383 files were found. Displaying the first 5:**
# - Name: USGS 1 Arc Second n36w078 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c1281d4be0260c2c46590
#
# - Name: USGS 1 Arc Second n36w079 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c1281d4be0260c2c4658e
#
# - Name: USGS 1 Arc Second n36w080 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b72d34e9bcc607bd4ac
#
# - Name: USGS 1 Arc Second n36w081 20240510
#   Publication Date: 2024-05-10
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/6642eff7d34e1955f5a42022
#
# - Name: USGS 1 Arc Second n36w081 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b71d34e9bcc607bd4aa

# %%
# Save raw list
available_30m_dem_list_path = project_root_path / 'data/bronze/json_docs/available_30m_dem_list.json'
available_30m_dem_list_path.parent.mkdir(parents=True, exist_ok=True)
with open(available_30m_dem_list_path, 'w', encoding='utf-8') as f:
    json.dump(response_dem_1arc_availabilty_json, f, ensure_ascii=False, indent=4)

# %% [markdown]
# **Filter latest 1 Arc-Second  DEM files**

# %%
dem_1arc_all_items = response_dem_1arc_availabilty_json.get("items",[])
dem_1arc_filtered_data = filter_latest_geotiff(data = dem_1arc_all_items)

# Display the dataset information
display(Markdown(f'**{len(dem_filtered_data)} unique 1 arc-second files were found. Displaying the first 5:**\n '))
count =  0
for dataset in dem_filtered_data:
    count += 1
    if count > 5:
        break
    print(f"- Name: {dataset['title']}")
    print(f"  Publication Date: {dataset['publicationDate']}")
    print(f"  Description: {dataset['body']}")
    print(f"  Metadata URL: {dataset['metaUrl']}\n")
# Out:
# **104 unique 1 arc-second files were found. Displaying the first 5:**
# - Name: USGS 1/3 Arc Second n36w078 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c7
#
# - Name: USGS 1/3 Arc Second n36w079 20250507
#   Publication Date: 2025-05-07
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/681c128ed4be0260c2c465c5
#
# - Name: USGS 1/3 Arc Second n36w080 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b89d34e9bcc607bd4c1
#
# - Name: USGS 1/3 Arc Second n36w081 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b88d34e9bcc607bd4bf
#
# - Name: USGS 1/3 Arc Second n36w082 20240611
#   Publication Date: 2024-06-11
#   Description: This tile of the 3D Elevation Program (3DEP) seamless products is 1/3 Arc Second resolution. 3DEP data serve as the elevation layer of The National Map, and provide basic elevation information for Earth science studies and mapping applications in the United States. Scientists and resource managers use 3DEP data for global change research, hydrologic modeling, resource monitoring, mapping and visualization, and many other applications. 3DEP data compose an elevation dataset that consists of seamless layers and a high resolution layer. Each of these layers consists of the best available raster elevation data of the conterminous United States, Alaska, Hawaii, territorial islands, Mexico and Canada. 3DEP data are updated continually as new data become available. Seamless 3DEP data are derived from diverse source data that are processed to a common coordinate system and unit of vertical measure. These data are distributed in geographic coordinates in units of decimal degrees, and in conformance with the North American Datum of 1983 (NAD 83). All elevation values are in meters and, over the conterminous United States, are referenced to the North American Vertical Datum of 1988 (NAVD 88). The vertical reference will vary in other areas. Seamless 3DEP data are available nationally (except for Alaska) at resolutions of 1 arc-second (approximately 30 meters) and 1/3 arc-second (approximately 10 meters). In most of Alaska, only lower resolution source data are available. As a result, most seamless 3DEP data for Alaska are at 2 arc-second (approximately 60 meters) grid spacing. Part of Alaska is available at the 1 and 1/3 arc-second resolutions from interferometric synthetic aperture radar (ifsar) collections starting in 2010. Plans are in place for collection of statewide ifsar in Alaska. All 3DEP products are public domain.
#   Metadata URL: https://www.sciencebase.gov/catalog/item/66692b86d34e9bcc607bd4bd

# %% [markdown]
# **Get the total size of 1 arc-second resolution DEM files**

# %%
# Get list of download links
download_1arc_urls_list = [item['downloadURL'] for item in dem_1arc_filtered_data]

# Call the function and get the total size
overall_total_size = get_total_tiff_size(download_1arc_urls_list)
# Out:
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w078/USGS_1_n36w078_20250507.tif: 61082287 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w079/USGS_1_n36w079_20250507.tif: 59561408 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w080/USGS_1_n36w080_20240611.tif: 59565558 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w081/USGS_1_n36w081_20240611.tif: 57343520 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w082/USGS_1_n36w082_20240611.tif: 57611101 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w083/USGS_1_n36w083_20220512.tif: 57595140 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w084/USGS_1_n36w084_20220725.tif: 58007875 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w085/USGS_1_n36w085_20220725.tif: 57734248 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w086/USGS_1_n36w086_20220729.tif: 56964769 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w087/USGS_1_n36w087_20230130.tif: 56855069 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w088/USGS_1_n36w088_20230130.tif: 60161420 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w089/USGS_1_n36w089_20220729.tif: 58910996 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n36w090/USGS_1_n36w090_20221121.tif: 56384143 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w078/USGS_1_n37w078_20250507.tif: 60629974 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w079/USGS_1_n37w079_20250507.tif: 59257963 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w080/USGS_1_n37w080_20210305.tif: 59249258 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w081/USGS_1_n37w081_20240611.tif: 57468128 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w082/USGS_1_n37w082_20240611.tif: 57326990 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w083/USGS_1_n37w083_20240923.tif: 58596423 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w084/USGS_1_n37w084_20240923.tif: 58902875 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w085/USGS_1_n37w085_20240923.tif: 59028077 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w086/USGS_1_n37w086_20240923.tif: 59199979 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w087/USGS_1_n37w087_20240923.tif: 57725015 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w088/USGS_1_n37w088_20230407.tif: 58388777 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w089/USGS_1_n37w089_20230123.tif: 55082139 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n37w090/USGS_1_n37w090_20231226.tif: 52708814 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n38w078/USGS_1_n38w078_20211220.tif: 62430155 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n38w079/USGS_1_n38w079_20211229.tif: 60926829 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n38w080/USGS_1_n38w080_20211229.tif: 58586128 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n38w081/USGS_1_n38w081_20230816.tif: 57483868 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/
bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w083/USGS_1_n42w083_20230717.tif: 25093497 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w084/USGS_1_n42w084_20230717.tif: 43434158 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w085/USGS_1_n42w085_20230717.tif: 50703304 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w086/USGS_1_n42w086_20210617.tif: 52340460 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w087/USGS_1_n42w087_20210617.tif: 48336310 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w088/USGS_1_n42w088_20241107.tif: 41971053 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w089/USGS_1_n42w089_20241107.tif: 52842750 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n42w090/USGS_1_n42w090_20240104.tif: 53497880 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w078/USGS_1_n43w078_20230227.tif: 55081398 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w079/USGS_1_n43w079_20220429.tif: 53606508 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w080/USGS_1_n43w080_20211122.tif: 27216411 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w081/USGS_1_n43w081_20210630.tif: 14210123 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w085/USGS_1_n43w085_20220815.tif: 52511019 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w088/USGS_1_n43w088_20241107.tif: 12251375 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w089/USGS_1_n43w089_20241107.tif: 52253664 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w090/USGS_1_n43w090_20240625.tif: 54396822 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n40w084/USGS_1_n40w084_20200302.tif: 53556874 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w082/USGS_1_n43w082_20130911.tif: 15965617 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w083/USGS_1_n43w083_20190401.tif: 24122019 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w084/USGS_1_n43w084_20190412.tif: 51361250 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w086/USGS_1_n43w086_20191107.tif: 54058250 bytes
# Successfully retrieved size for https://prd-tnm.s3.amazonaws.com/StagedProducts/Elevation/1/TIFF/historical/n43w087/USGS_1_n43w087_20190308.tif: 17391984 bytes
#
# --- Summary ---
# Attempted to process 104 URLs.
# Successfully processed 104 URLs.
# Total size of processed files: 5574.588097 Mega bytes
# ---------------

# %%
# Save raw list
filtered_30m_dem_list_path = project_root_path / 'data/silver/json_docs/filtered_30m_dem_list.json'
filtered_30m_dem_list_path.parent.mkdir(parents=True, exist_ok=True)
with open(filtered_30m_dem_list_path, 'w', encoding='utf-8') as f:
    json.dump(dem_1arc_filtered_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# The total size of 1 Arc-Second GeoTiff files is about **5.6 Gb**, significantly smaller than the 1/3 Arc-Second resolution. Although a coarser resolution does not offer fine details as higher resolution, the overall size, of 1/3 Arc-Second does not justify the processing capacity that should be added to this project. Therefore, 1 Arc-Second resolution is chosen for this study.
#
# ## 1 Arc-Second DEM Download
#
# This section downloads the 1 Arc-Second geoTiff files for the study area.

# %%
# Load document containing download link
filtered_30m_dem_list_path = project_root_path / 'data/silver/json_docs/filtered_30m_dem_list.json'
with open(filtered_30m_dem_list_path, 'r') as file:
    dem_list = json.load(file)

count = 0
total_files = len(dem_list)

# Download the DEM 1 arcsec file
for item in dem_list:
    count += 1
    try:
        url = item.get('downloadURL')
        
        item_base_name = os.path.basename(url)
        item_local_path = project_root_path / 'data/bronze' / 'geo' / 'raster' / 'dem1arcsec' / item_base_name
        
        if not item_local_path.exists():
            print(f'Downloading {item.get("title")} file {count} of {total_files}...')
            download_GeoTIFF(url=url, filename=item_local_path, chunk_size=1024*1024)
            
        else:
            print(f'{item_base_name} already exists.\n')

    except Exception as err:
        print(f'Failed to download file: {err}')
        continue
# Out:
# Downloading USGS 1 Arc Second n36w078 20250507 file 1 of 104...
# Downloading file USGS_1_n40w078_20230620.tif...
# Downloaded: USGS_1_n40w078_20230620.tif.00%)
# Function 'download_GeoTIFF' executed in 9.0637 seconds.
# Downloading USGS 1 Arc Second n40w079 20230816 file 54 of 104...
# Downloading file USGS_1_n40w079_20230816.tif...
# Downloaded: USGS_1_n40w079_20230816.tif.00%)
# Function 'download_GeoTIFF' executed in 10.0687 seconds.
# Downloading USGS 1 Arc Second n40w080 20230816 file 55 of 104...
# Downloading file USGS_1_n40w080_20230816.tif...
# Downloaded: USGS_1_n40w080_20230816.tif.00%)
# Function 'download_GeoTIFF' executed in 12.1973 seconds.
# Downloading USGS 1 Arc Second n40w081 20230911 file 56 of 104...
# Downloading file USGS_1_n40w081_20230911.tif...
# Downloaded: USGS_1_n40w081_20230911.tif.00%)
# Function 'download_GeoTIFF' executed in 11.4003 seconds.
# Downloading USGS 1 Arc Second n40w082 20230911 file 57 of 104...
# Downloading file USGS_1_n40w082_20230911.tif...
# Downloaded: USGS_1_n40w082_20230911.tif.00%)
# Function 'download_GeoTIFF' executed in 10.7995 seconds.
# Downloading USGS 1 Arc Second n40w083 20230911 file 58 of 104...
# Downloading file USGS_1_n40w083_20230911.tif...
# Downloaded: USGS_1_n40w083_20230911.tif.00%)
# Function 'download_GeoTIFF' executed in 19.4489 seconds.
# Downloading USGS 1 Arc Second n40w085 20230407 file 59 of 104...
# Downloading file USGS_1_n40w085_20230407.tif...
# Downloaded: USGS_1_n40w085_20230407.tif.00%)
# Function 'download_GeoTIFF' executed in 8.7832 seconds.
# Downloading USGS 1 Arc Second n40w086 20210617 file 60 of 104...
# Downloading file USGS_1_n40w086_20210617.tif...
# Downloaded: USGS_1_n40w086_20210617.tif.00%)
# Function 'download_GeoTIFF' executed in 11.6754 seconds.
# Downloading USGS 1 Arc Second n40w087 20210617 file 61 of 104...
# Downloading file USGS_1_n40w087_20210617.tif...
# Downloaded: USGS_1_n40w087_20210617.tif.00%)
# Function 'download_GeoTIFF' executed in 10.2769 seconds.
# Downloading USGS 1 Arc Second n40w088 20221205 file 62 of 104...
# Downloading file USGS_1_n40w088_20221205.tif...
# Downloaded: USGS_1_n40w088_20221205.tif.00%)
# Function 'download_GeoTIFF' executed in 10.3899 seconds.
# Downloading USGS 1 Arc Second n40w089 20240104 file 63 of 104...
# Downloading file USGS_1_n40w089_20240104.tif...
# Downloaded: USGS_1_n40w089_20240104.tif.00%)
# Function 'download_GeoTIFF' executed in 9.0689 seconds.
# Downloading USGS 1 Arc Second n40w090 20230303 file 64 of 104...
# Downloading file USGS_1_n40w090_20230303.tif...
# Downloaded: USGS_1_n40w090_20230303.tif.00%)
# Function 'download_GeoTIFF' executed in 11.7722 seconds.
# Downloading USGS 1 Arc Second n41w078 20220429 file 65 of 104...
# Downloading file USGS_1_n41w078_20220429.tif...
# Downloaded: USGS_1_n41w078_20220429.tif.00%)
# Function 'download_GeoTIFF' executed in 10.1906 seconds.
# Downloading USGS 1 Arc Second n41w079 20220429 file 66 of 104...
# Downloading file USGS_1_n42w079_20220429.tif...
# Downloaded: USGS_1_n42w079_20220429.tif.00%)
# Function 'download_GeoTIFF' executed in 12.4570 seconds.
# Downloading USGS 1 Arc Second n42w080 20220429 file 80 of 104...
# Downloading file USGS_1_n42w080_20220429.tif...
# Downloaded: USGS_1_n42w080_20220429.tif.00%)
# Function 'download_GeoTIFF' executed in 11.8872 seconds.
# Downloading USGS 1 Arc Second n42w081 20230911 file 81 of 104...
# Downloading file USGS_1_n42w081_20230911.tif...
# Downloaded: USGS_1_n42w081_20230911.tif.00%)
# Function 'download_GeoTIFF' executed in 9.5629 seconds.
# Downloading USGS 1 Arc Second n42w082 20230911 file 82 of 104...
# Downloading file USGS_1_n42w082_20230911.tif...
# Downloaded: USGS_1_n42w082_20230911.tif.00%)
# Function 'download_GeoTIFF' executed in 7.6559 seconds.
# Downloading USGS 1 Arc Second n42w083 20230717 file 83 of 104...
# Downloading file USGS_1_n42w083_20230717.tif...
# Downloaded: USGS_1_n42w083_20230717.tif.00%)
# Function 'download_GeoTIFF' executed in 5.5749 seconds.
# Downloading USGS 1 Arc Second n42w084 20230717 file 84 of 104...
# Downloading file USGS_1_n42w084_20230717.tif...
# Downloaded: USGS_1_n42w084_20230717.tif.00%)
# Function 'download_GeoTIFF' executed in 8.9355 seconds.
# Downloading USGS 1 Arc Second n42w085 20230717 file 85 of 104...
# Downloading file USGS_1_n42w085_20230717.tif...
# Downloaded: USGS_1_n42w085_20230717.tif.00%)
# Function 'download_GeoTIFF' executed in 9.3943 seconds.
# Downloading USGS 1 Arc Second n42w086 20210617 file 86 of 104...
# Downloading file USGS_1_n42w086_20210617.tif...
# Downloaded: USGS_1_n42w086_20210617.tif.00%)
# Function 'download_GeoTIFF' executed in 9.1461 seconds.
# Downloading USGS 1 Arc Second n42w087 20210617 file 87 of 104...
# Downloading file USGS_1_n42w087_20210617.tif...
# Downloaded: USGS_1_n42w087_20210617.tif.00%)
# Function 'download_GeoTIFF' executed in 12.7779 seconds.
# Downloading USGS 1 Arc Second n42w088 20241107 file 88 of 104...
# Downloading file USGS_1_n42w088_20241107.tif...
# Downloaded: USGS_1_n42w088_20241107.tif.00%)
# Function 'download_GeoTIFF' executed in 9.5012 seconds.
# Downloading USGS 1 Arc Second n42w089 20241107 file 89 of 104...
# Downloading file USGS_1_n42w089_20241107.tif...
# Downloaded: USGS_1_n42w089_20241107.tif.00%)
# Function 'download_GeoTIFF' executed in 10.6358 seconds.
# Downloading USGS 1 Arc Second n42w090 20240104 file 90 of 104...
# Downloading file USGS_1_n42w090_20240104.tif...
# Downloaded: USGS_1_n42w090_20240104.tif.00%)
# Function 'download_GeoTIFF' executed in 8.7515 seconds.
# Downloading USGS 1 Arc Second n43w078 20230227 file 91 of 104...
# Downloading file USGS_1_n43w078_20230227.tif...
# Downloaded: USGS_1_n43w078_20230227.tif.00%)
# Function 'download_GeoTIFF' executed in 12.5965 seconds.
# Downloading USGS 1 Arc Second n43w079 20220429 file 92 of 104...
# Downloading file USGS_1_n43w079_20220429.tif...
# Downloaded: USGS_1_n43w079_20220429.tif.00%)
# Function 'download_GeoTIFF' executed in 10.1798 seconds.
# Downloading USGS 1 Arc Second n43w080 20211122 file 93 of 104...
# Downloading file USGS_1_n43w080_20211122.tif...
# Downloaded: USGS_1_n43w080_20211122.tif.00%)
# Function 'download_GeoTIFF' executed in 24.2738 seconds.
# Downloading USGS 1 Arc Second n43w081 20210630 file 94 of 104...
# Downloading file USGS_1_n43w081_20210630.tif...
# Downloaded: USGS_1_n43w081_20210630.tif.00%)
# Function 'download_GeoTIFF' executed in 4.4775 seconds.
# Downloading USGS 1 Arc Second n43w085 20220815 file 95 of 104...
# Downloading file USGS_1_n43w085_20220815.tif...
# Downloaded: USGS_1_n43w085_20220815.tif.00%)
# Function 'download_GeoTIFF' executed in 11.0199 seconds.
# Downloading USGS 1 Arc Second n43w088 20241107 file 96 of 104...
# Downloading file USGS_1_n43w088_20241107.tif...
# Downloaded: USGS_1_n43w088_20241107.tif.00%)
# Function 'download_GeoTIFF' executed in 4.0505 seconds.
# Downloading USGS 1 Arc Second n43w089 20241107 file 97 of 104...
# Downloading file USGS_1_n43w089_20241107.tif...
# Downloaded: USGS_1_n43w089_20241107.tif.00%)
# Function 'download_GeoTIFF' executed in 9.1427 seconds.
# Downloading USGS 1 Arc Second n43w090 20240625 file 98 of 104...
# Downloading file USGS_1_n43w090_20240625.tif...
# Downloaded: USGS_1_n43w090_20240625.tif.00%)
# Function 'download_GeoTIFF' executed in 19.0636 seconds.
# Downloading USGS 1 arc-second n40w084 1 x 1 degree file 99 of 104...
# Downloading file USGS_1_n40w084_20200302.tif...
# Downloaded: USGS_1_n40w084_20200302.tif.00%)
# Function 'download_GeoTIFF' executed in 9.6179 seconds.
# Downloading USGS 1 arc-second n43w082 1 x 1 degree file 100 of 104...
# Downloading file USGS_1_n43w082_20130911.tif...
# Downloaded: USGS_1_n43w082_20130911.tif.00%)
# Function 'download_GeoTIFF' executed in 4.7858 seconds.
# Downloading USGS 1 arc-second n43w083 1 x 1 degree file 101 of 104...
# Downloading file USGS_1_n43w083_20190401.tif...
# Downloaded: USGS_1_n43w083_20190401.tif.00%)
# Function 'download_GeoTIFF' executed in 5.9100 seconds.
# Downloading USGS 1 arc-second n43w084 1 x 1 degree file 102 of 104...
# Downloading file USGS_1_n43w084_20190412.tif...
# Downloaded: USGS_1_n43w084_20190412.tif.00%)
# Function 'download_GeoTIFF' executed in 10.8138 seconds.
# Downloading USGS 1 arc-second n43w086 1 x 1 degree file 103 of 104...
# Downloading file USGS_1_n43w086_20191107.tif...
# Downloaded: USGS_1_n43w086_20191107.tif.00%)
# Function 'download_GeoTIFF' executed in 13.0874 seconds.
# Downloading USGS 1 arc-second n43w087 1 x 1 degree file 104 of 104...
# Downloading file USGS_1_n43w087_20190308.tif...
# Downloaded: USGS_1_n43w087_20190308.tif.00%)
# Function 'download_GeoTIFF' executed in 4.8972 seconds.
